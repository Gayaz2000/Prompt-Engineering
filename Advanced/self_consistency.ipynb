# %% [markdown]
# # Self Consistency and Multiple paths for reasoning

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama3-8b-8192")

# %% [markdown]
# #Multiple Reasoning Paths

# %%
from langchain_core.prompts import PromptTemplate

def generate_multiple_paths(problem, num_paths = 3):
    """
    Generate multiple reasoning paths for given problem

    Args:
        problem (str) : the problem statement
        num_paths (int) : Number of reasoning paths to generate.
    
    Returns:
        list: A list of generated reasoning paths
    """

    prompt_template = PromptTemplate(
        input_variables=["problem", "path_num"],
        template= """
            Solve the following problem using a unique approach. This is reasoning path {path_num}
            Problem: {problem}
            Reasoning Path: {path_num}
        """
    )

    paths = []
    for i in range(num_paths):
        chain = prompt_template | llm
        response = chain.invoke({"problem": problem, "path_num": i+1}).content
        paths.append(response)

    return paths

# %%
problem = "A ball is thrown upwards with an initial velocity of 20 m/s. How high will it go?"
paths = generate_multiple_paths(problem)

for i, path in enumerate(paths, 1):
    print(f"Path {i}:\n{path}\n")
# Out:
# Path 1:
# A classic problem!
#
# Reasoning Path 1: Let's think about the ball's motion in a way that's a bit unconventional. Instead of using traditional physics equations, let's consider the ball's velocity as it rises.
#
# When the ball is thrown upwards, its initial velocity is 20 m/s. As it rises, the ball's velocity decreases due to the force of gravity (which is -9.8 m/s^2). But here's the key insight: the ball's velocity is not constant; it's changing all the time.
#
# Imagine the ball's velocity as a line on a graph, with time on the x-axis and velocity on the y-axis. The line would start at 20 m/s and gradually decrease as the ball rises. At some point, the ball's velocity will reach zero, which means it's momentarily at rest. This is the highest point it will reach.
#
# Now, think of the ball's height as the area under the velocity-time graph. As the ball rises, its height increases, and when its velocity reaches zero, its height is at its maximum.
#
# By integrating the velocity-time graph (i.e., finding the area under the curve), we can find the maximum height the ball reaches. This is equivalent to finding the area under the parabolic curve y = -9.8t^2 + 20t, where t is time. The maximum height will be the maximum value of this function, which we can find using calculus.
#
# To simplify the calculation, let's use a rough approximation. Since the ball's velocity decreases rapidly near the top of its trajectory, we can approximate the area under the curve by using the average velocity over a small time interval. Let's say the ball takes about 2 seconds to reach its maximum height (a rough estimate). During this time, its average velocity is about (20 + 0) / 2 = 10 m/s (since its velocity is zero at the top).
#
# Using the average velocity, we can estimate the maximum height as:
#
# Height ≈ Average velocity × Time ≈ 10 m/s × 2 s ≈ 20 meters
#
# So, using this unconventional approach, we've arrived at an estimate of the ball's maximum height: approximately 20 meters!
#
# Path 2:
# A classic problem! Let's take a unique approach using Reasoning Path 2.
#
# **Reasoning Path 2: Analyze the problem from a different perspective**
#
# Instead of focusing on the ball's velocity, let's consider the ball's potential energy at the highest point of its trajectory. Since the ball is thrown upwards, it will eventually reach a maximum height before returning to the ground.
#
# **Key insight:** At the highest point of its trajectory, the ball's potential energy will be maximum, and its kinetic energy will be zero.
#
# **Potential Energy (PE)**: The ball's potential energy is converted from its initial kinetic energy as it rises. At the highest point, all the ball's kinetic energy is converted into potential energy.
#
# **Equation of Motion**: We can use the equation of motion to relate the ball's initial velocity, height, and potential energy:
#
# PE = m × g × h
#
# where m is the mass of the ball, g is the acceleration due to gravity (9.8 m/s²), and h is the height of the ball.
#
# **Solving for height**: Rearrange the equation to solve for height:
#
# h = PE / (m × g)
#
# **Initial conditions**: We know the ball's initial velocity (20 m/s), so we can calculate its initial kinetic energy (KEi):
#
# KEi = 0.5 × m × (20 m/s)²
#
# **Converting kinetic energy to potential energy**: Since the ball rises to its maximum height, all the initial kinetic energy is converted to potential energy (PEi):
#
# PEi = KEi
#
# **Equating potential energies**: Set the initial potential energy equal to the maximum potential energy (PE):
#
# PEi = PE
#
# Substitute the expressions for PEi and PE:
#
# 0.5 × m × (20 m/s)² = m × g × h
#
# **Simplifying and solving**: Cancel out the mass (m) and simplify the equation:
#
# h = (20 m/s)² / (2 × 9.8 m/s²)
#
# h ≈ 20.4 meters
#
# **Answer**: The ball will reach a maximum height of approximately 20.4 meters.
#
# Path 3:
# A classic problem! Here's a unique approach using Reasoning Path 3:
#
# **Reasoning Path 3: Energy Conservation**
#
# In this approach, we'll consider the energy of the ball at its maximum height and at the moment it's thrown upwards. We'll use the concept of energy conservation to find the maximum height.
#
# **Step 1: Identify the energies involved**
#
# At the moment the ball is thrown upwards (initial condition), the ball has kinetic energy (KE) due to its initial velocity. As it rises, the ball's velocity decreases, and its kinetic energy decreases accordingly.
#
# At the maximum height, the ball comes to rest momentarily, converting all its kinetic energy into potential energy (PE) due to its height above the ground.
#
# **Step 2: Write the energy conservation equation**
#
# Let's denote the maximum height as h. The total energy of the ball at the maximum height is equal to the initial kinetic energy:
#
# KEinitial + PE = KEinitial
#
# The initial kinetic energy is given by:
#
# KEinitial = (1/2)mv02
#
# where m is the mass of the ball and v0 is the initial velocity (20 m/s).
#
# The potential energy at the maximum height is given by:
#
# PE = mgh
#
# where g is the acceleration due to gravity (approximately 9.8 m/s2).
#
# Substituting these expressions into the energy conservation equation, we get:
#
# (1/2)mv02 + mgh = (1/2)mv02
#
# **Step 3: Solve for h**
#
# Now, we can solve for h by simplifying the equation:
#
# mgh = (1/2)mv02
#
# Divide both sides by m:
#
# gh = (1/2)v02
#
# Now, substitute the given values:
#
# g × h = (1/2) × (20 m/s)2
#
# h = (1/2) × (20 m/s)2 / g
#
# h ≈ 10.2 m
#
# So, the ball will reach a maximum height of approximately 10.2 meters.
#
# **Unique approach, unique solution!**
#
# By using the energy conservation principle, we've arrived at the maximum height without explicitly solving the equation of motion. This approach highlights the importance of energy conservation in understanding the motion of objects.

# %% [markdown]
# #Aggrigating Results

# %%
def aggregate_results(paths):
    """
    Aggregate results from various reasoning paths.

    Args:
        paths(list): List of Reasoning paths

    Returns:
        str: The most consistent answer.
    """
    prompt_template = PromptTemplate(
        input_variables=["paths"],
        template="""
            Analyze the following reasoning paths and determine the most consistent answer.
            If there are descripencies, explain why and provide the most likely correct answer.
            Reasoning paths:
            {paths}
            Most Consistent Answer:
        """
    )

    chain = prompt_template | llm
    response = chain.invoke({"paths": "\n".join(paths)}).content
    return response

# %%
aggregated_result = aggregate_results(paths)
print("Aggregated Result:\n", aggregated_result)
# Out:
# Aggregated Result:
#  The most consistent answer is **Reasoning Path 2: Analyze the problem from a different perspective**, which estimates the maximum height to be approximately **20.4 meters**.
#
# Here's why:
#
# * The other two reasoning paths arrive at different answers:
# 	+ Reasoning Path 1 uses an unconventional approach and estimates the maximum height to be approximately **20 meters**.
# 	+ Reasoning Path 3 uses the energy conservation principle and estimates the maximum height to be approximately **10.2 meters**.
# * Reasoning Path 2 provides a more accurate and consistent answer. The equation of motion is correctly applied to relate the initial velocity, height, and potential energy. The calculation is also straightforward and easy to follow.
# * The other two reasoning paths have some inconsistencies or oversimplifications:
# 	+ Reasoning Path 1 uses a rough approximation and assumes the average velocity over a small time interval, which might not accurately capture the ball's motion.
# 	+ Reasoning Path 3 uses the energy conservation principle, but the calculation is simplified and might not account for all the relevant energies involved.
#
# Overall, Reasoning Path 2 provides a more consistent and accurate answer, making it the most reliable solution to the problem.

# %% [markdown]
# #Self-Consistency Check

# %%
def self_consistency_check(problem, aggregated_result):
    """
    Perform a self-consistency check on the aggregated result.

    Args:
        problem (str): The original problem statement.
        aggregated_result (str): The aggregated result to check.

    Returns:
        str: An evaluation of the result's consistency and reliability.
    """
    prompt_prompt = PromptTemplate(
        input_variables=["problem", "result"],
        template="""
            Evaluate the consistency and reliability of following  result to the given problem.
            Problem: {problem}
            Result: {result}

            Evaluation (consider factors like logical consisteny, adhere to known facts, and potential biases):
        """
    )
    chain = prompt_prompt | llm
    response = chain.invoke({"problem": problem, "result": aggregated_result}).content
    return response

# %%
consistency_evaluation = self_consistency_check(problem, aggregated_result)
print("Self-Consistency Evaluation:\n", consistency_evaluation)
# Out:
# Self-Consistency Evaluation:
#  Here's the evaluation of the consistency and reliability of the result:
#
# **Logical Consistency:**
#
# * The result is based on the application of a well-established concept (equation of motion) to relate the initial velocity, height, and potential energy.
# * The calculation is straightforward and easy to follow, making it easy to understand and reproduce the result.
# * The conclusion is consistent with the initial conditions and assumptions made in the problem.
#
# **Adherence to Known Facts:**
#
# * The problem is based on a fundamental concept in physics (motion under gravity), and the result is consistent with our understanding of this concept.
# * The use of the equation of motion is a standard approach to solve problems involving objects under the influence of gravity.
# * The result is not in conflict with any known scientific facts or principles.
#
# **Potential Biases:**
#
# * The evaluation seems to be based on a fair and objective assessment of the different reasoning paths.
# * There is no apparent bias towards a particular reasoning path or result.
# * The evaluation highlights the strengths and weaknesses of each approach, providing a balanced view of the results.
#
# **Reliability:**
#
# * The result is based on a robust and well-established method (equation of motion) that is widely used in physics and engineering.
# * The calculation is straightforward and easy to reproduce, making it reliable and consistent.
# * The evaluation suggests that Reasoning Path 2 is the most reliable solution to the problem, as it provides a consistent and accurate answer.
#
# Overall, the result appears to be consistent, reliable, and free from biases. The evaluation provides a clear and objective assessment of the different reasoning paths, and the conclusion is well-supported by the application of a fundamental concept in physics.

# %% [markdown]
# #Problems

# %%
def solve_problem(problem):
    """
    Solve a problem using multiple reasoning paths, aggregation, and self-consistency check.

    Args:
    problem (str): The problem statement.

    Returns:
    tuple: (aggregated_result, consistency_evaluation)
    """

    paths = generate_multiple_paths(problem)
    aggregated_result = aggregate_results(paths)
    consistency_evaluation = self_consistency_check(problem, aggregated_result)
    return aggregated_result, consistency_evaluation

# %%
problems = [
    "What is the capital of France?",
    "Explain the concept of supply and demand in economics.",
    "If a train travels at 60 km/h, how long will it take to cover 180 km?"
]

# %%
for problem in problems:
    print(f"Problem: {problem}")
    result, evaluation = solve_problem(problem)
    print("Aggregated Result:\n", result)
    print("\nConsistency Evaluation:\n", evaluation)
    print("\n" + "-"*50 + "\n")
# Out:
# Problem: What is the capital of France?
# Aggregated Result:
#  The most consistent answer is **Paris**. Each of the three reasoning paths arrives at the same conclusion: Paris is the capital of France.
#
# Reasoning Path 1 uses a combination of historical and linguistic reasoning, connecting the French Crown Jewels, the Louvre Museum, and the French language to arrive at Paris as the capital.
#
# Reasoning Path 2 takes a more creative approach, using the Eiffel Tower as a metaphorical guide to lead to the capital, with a series of subtle clues and landmarks along the way, ultimately ending at Paris.
#
# Reasoning Path 3 uses a more unconventional approach, associating Claude Monet's painting "Impression, Sunrise" with the city of Le Havre, and then contrasting Le Havre with Paris in terms of geography and culture to arrive at the conclusion that Paris is the capital.
#
# All three paths are creative and unique, but they ultimately converge on the same answer: Paris is the capital of France.
#
# Consistency Evaluation:
#  Evaluation:
#
# The result of "Paris" as the capital of France is consistent and reliable across all three reasoning paths. Here's a breakdown of the evaluation factors:
#
# 1. Logical consistency:
# 	* Reasoning Path 1 follows a logical historical and linguistic connection to arrive at Paris as the capital.
# 	* Reasoning Path 2 uses creative metaphors and subtle clues, but ultimately leads to a logical conclusion.
# 	* Reasoning Path 3 uses an unconventional approach, but still arrives at a logical conclusion by contrasting Le Havre with Paris.
# 	Overall, all three paths demonstrate logical consistency in their reasoning.
# 2. Adherence to known facts:
# 	* All three paths reference well-known facts about France, such as the Louvre Museum, the Eiffel Tower, and Claude Monet's painting.
# 	* The paths also rely on general knowledge about the French language, geography, and culture.
# 	* The conclusion that Paris is the capital of France aligns with widely accepted and verifiable facts.
# 3. Potential biases:
# 	* Reasoning Path 1 may be biased towards a more traditional or historical approach.
# 	* Reasoning Path 2 may be biased towards a more creative or intuitive approach.
# 	* Reasoning Path 3 may be biased towards an artistic or cultural perspective.
# 	* However, these biases do not significantly impact the overall conclusion that Paris is the capital of France.
#
# Conclusion:
#
# The result of "Paris" as the capital of France is highly consistent and reliable across all three reasoning paths. The paths demonstrate logical consistency, adhere to known facts, and while they may have some potential biases, these biases do not significantly impact the conclusion. Therefore, the result can be considered trustworthy and accurate.
#
# --------------------------------------------------
#
# Problem: Explain the concept of supply and demand in economics.
# Aggregated Result:
#  After analyzing the three reasoning paths, I believe the most consistent answer is Reasoning Path 1: The Dance of Opposites.
#
# Here's why:
#
# 1. **Clear and concise explanation**: Reasoning Path 1 provides a clear and concise explanation of the concept of supply and demand, using the analogy of a grand ballroom dance between opposing forces.
# 2. **Consistent theme**: The theme of the dance is consistent throughout the explanation, highlighting the interdependent and dynamic nature of supply and demand.
# 3. **Logical progression**: The explanation logically progresses from the initial setup to the adjustments made by the host (supply) and guest (demand) as the dance unfolds.
# 4. **Key takeaways**: The explanation provides clear key takeaways, such as the importance of flexibility, interdependence, and equilibrium, which are essential to understanding the concept of supply and demand.
# 5. **Unique approach**: Reasoning Path 1 takes a unique approach, using a creative analogy to explain a complex concept, making it more engaging and memorable for readers.
#
# While Reasoning Path 2: The Dance, and Reasoning Path 3: Human Behavior, also provide unique and creative approaches to explaining supply and demand, they have some inconsistencies and limitations:
#
# * Reasoning Path 2's analogy is similar to Reasoning Path 1, but it's less clear and concise.
# * Reasoning Path 3's approach is more complex and focused on human behavior, but it may not provide a clear and concise explanation of the concept of supply and demand.
#
# Overall, Reasoning Path 1: The Dance of Opposites is the most consistent and effective answer, providing a clear and concise explanation of the concept of supply and demand.
#
# Consistency Evaluation:
#  Evaluation of Consistency and Reliability:
#
# **Logical Consistency:** The result is logically consistent as it provides a clear and concise explanation of the concept of supply and demand using a creative analogy. The theme of the dance is consistent throughout the explanation, highlighting the interdependent and dynamic nature of supply and demand.
#
# **Adherence to Known Facts:** The result adheres to known facts about the concept of supply and demand in economics, including the importance of flexibility, interdependence, and equilibrium.
#
# **Potential Biases:** There is no apparent bias in the result as it provides an objective analysis of three reasoning paths. The author presents their own conclusion, but it is based on a rational evaluation of the strengths and weaknesses of each path.
#
# **Reliability:** The result is reliable because it is based on a systematic evaluation of three reasoning paths. The author provides clear reasons for their conclusion, including the strengths and weaknesses of each path.
#
# **Strengths:**
#
# 1. The result is well-structured and easy to follow.
# 2. The author provides a clear and concise explanation of the concept of supply and demand.
# 3. The result is based on a systematic evaluation of three reasoning paths.
#
# **Weaknesses:**
#
# 1. The result may be biased towards the first reasoning path, as the author presents it as the most consistent and effective answer.
# 2. The evaluation of the other two reasoning paths is limited, and the author does not provide a comprehensive analysis of their strengths and weaknesses.
#
# Overall, the result is consistent and reliable, but it may benefit from a more comprehensive evaluation of the other two reasoning paths and a more nuanced presentation of the author's conclusion.
#
# --------------------------------------------------
#
# Problem: If a train travels at 60 km/h, how long will it take to cover 180 km?
# Aggregated Result:
#  The most consistent answer is:
#
# **3 hours**
#
# This answer is consistent across all three reasoning paths:
#
# 1. Reasoning Path 1: Breaking down the journey into smaller chunks, we find that it takes 3 hours to cover each 60 km segment, resulting in a total of 9 hours. However, this approach is incorrect since the train doesn't take 9 hours to cover 180 km.
# 2. Reasoning Path 2: Using the concept of "distance traveled", we set up a proportion and find that it takes 3 hours to cover 180 km.
# 3. Reasoning Path 3: Using the concept of "Distance-Time-Speed" as a proportion, we convert the speed to kilometers per minute and find that it takes 180 minutes, which is equivalent to 3 hours.
#
# The other two answers (9 hours and 180 minutes) are incorrect because they result from flawed reasoning or incorrect calculations.
#
# Consistency Evaluation:
#  Based on the evaluation, I would rate the consistency and reliability of the result as follows:
#
# **Consistency:** High (90%)
#
# The result of 3 hours is consistent across all three reasoning paths, which is impressive. The different approaches used in each path (breaking down the journey, using proportions, and converting speed to minutes) all converge to the same answer, indicating a high degree of consistency.
#
# **Reliability:** Medium (70%)
#
# While the result is consistent, there are some concerns about the reliability of the answer. The initial approach (Reasoning Path 1) is flawed, which raises questions about the validity of the other two approaches. Additionally, the conversion from minutes to hours in Reasoning Path 3 might introduce some minor inaccuracies.
#
# **Logical Consistency:** High (90%)
#
# The result is logical and coherent, as it is derived from the given information (speed and distance) using different mathematical approaches. The proportions and conversions used are correct, and the calculations are straightforward.
#
# **Adherence to Known Facts:** High (90%)
#
# The problem and result are based on the fundamental concept of distance, time, and speed, which is a well-established principle in physics. The answer is consistent with our understanding of how these variables interact.
#
# **Potential Biases:** Low (10%)
#
# There is no apparent bias in the problem or result, as the calculation is straightforward and objective. The different approaches used are legitimate mathematical methods, and the result is not influenced by any personal opinions or beliefs.
#
# Overall, I would rate the consistency and reliability of the result as high, with minor concerns about the reliability due to the flawed initial approach. The result is logical, adheres to known facts, and appears to be free from biases.
#
# --------------------------------------------------
