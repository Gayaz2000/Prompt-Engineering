# %% [markdown]
# # Ethics Consideration in Prompts

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate

llm = ChatGroq(model="llama3-8b-8192", max_tokens=1000)

# %% [markdown]
# #Understanding Bias in AI

# %%
biased_prompt = "Describe a typical programmer."
biased_response = llm.invoke(biased_prompt)
print("Potentially biased response:")
print(biased_response.content)
# Out:
# Potentially biased response:
# The stereotype!
#
# A typical programmer is often perceived as a:
#
# 1. **Introverted and quiet**: Programmers tend to be more comfortable with code than with people, and may prefer to work independently or in small groups.
# 2. ** analytical and detail-oriented**: Programmers are known for their attention to detail, ability to break down complex problems, and logical thinking.
# 3. **Curious and problem-solvers**: Programmers are often passionate about learning and solving problems, and enjoy the challenge of figuring out how to overcome obstacles.
# 4. **Tech-savvy**: Programmers are typically proficient in multiple programming languages, frameworks, and technologies, and stay up-to-date with the latest trends and developments.
# 5. **Creative and innovative**: Despite the stereotype of programmers being introverted, many are creative and enjoy finding new and innovative solutions to problems.
# 6. **Flexible and adaptable**: Programmers are often used to working on multiple projects simultaneously, and are comfortable with changing priorities and deadlines.
# 7. **Coffee-fueled**: Programmers are often fueled by caffeine, and may have a go-to coffee shop or mug nearby.
# 8. **Casual dressers**: Programmers tend to dress in a relaxed, casual style, and may prioritize comfort over fashion.
# 9. **Geeky and proud**: Programmers often have a strong sense of pride in their work, and may be enthusiastic about sharing their knowledge and expertise with others.
# 10. **Late-night coders**: Programmers often work late into the night, fueled by adrenaline and a desire to meet project deadlines.
#
# Of course, these are just generalizations, and many programmers don't fit this stereotype. But for those who do, it's a fun and rewarding profession that allows them to combine their analytical and creative skills to build amazing things!

# %% [markdown]
# #Identifying and Mitigating Bias

# %%
inclusive_prompt = PromptTemplate(
    input_variables=["profession"],
    template="Describe the diverse range of individuals who work as {profession}, emphasizing the variety in their backgrounds, experiences, and characteristics."
)

inclusive_response = (inclusive_prompt | llm).invoke({"profession": "computer programmers"}).content
print("More inclusive response:")
print(inclusive_response)
# Out:
# More inclusive response:
# Computer programmers, also known as software developers, come from a diverse range of backgrounds, experiences, and characteristics. Here's a glimpse into the varied universe of programmers:
#
# **Demographics:**
#
# * Age: Programmers range from teenagers to retirees, with the majority falling between 25-45 years old.
# * Gender: While traditional stereotypes may suggest a male-dominated field, women make up around 25% of the programming workforce, and their numbers are growing.
# * Ethnicity: Programmers come from diverse ethnic backgrounds, including African, Asian, European, Latin American, and Indigenous communities.
# * Disability: Programmers with disabilities, such as visual or hearing impairments, are increasingly represented in the industry.
#
# **Educational backgrounds:**
#
# * Formal education: Many programmers hold degrees in computer science, software engineering, or related fields, while others may have learned through online courses, boot camps, or self-taught methods.
# * Non-traditional learners: Some programmers may come from non-technical backgrounds, such as arts, humanities, or social sciences, and have learned programming skills through online resources or on-the-job training.
#
# **Work experience:**
#
# * New graduates: Fresh out of college, some programmers start their careers with internships or entry-level positions.
# * Industry veterans: Experienced programmers have spent years working in various industries, such as finance, healthcare, or gaming.
# * Freelancers and entrepreneurs: Many programmers work as independent contractors or founders of their own companies, taking on a variety of projects and clients.
#
# **Characteristics:**
#
# * Problem-solvers: Programmers are often analytical thinkers, able to break down complex problems into manageable parts.
# * Creative: Despite the technical aspects, programming requires creativity and innovation to design and develop new solutions.
# * Collaborators: Programmers often work in teams, requiring strong communication and interpersonal skills.
# * Lifelong learners: The programming field is constantly evolving, so programmers must stay up-to-date with the latest technologies, frameworks, and best practices.
#
# **Specializations:**
#
# * Languages: Programmers may specialize in specific programming languages, such as Python, Java, C++, or JavaScript.
# * Domains: Some programmers focus on specific areas, such as:
# 	+ Web development (front-end, back-end, full-stack)
# 	+ Mobile app development (iOS, Android, cross-platform)
# 	+ Game development (game engines, game design)
# 	+ Data science and machine learning
# 	+ cybersecurity and penetration testing
# 	+ Artificial intelligence and robotics
#
# **Personal characteristics:**
#
# * Passion: Many programmers are driven by a passion for technology, innovation, and problem-solving.
# * Perseverance: Programming can be challenging, so programmers must be willing to learn from failures and persist in the face of obstacles.
# * Attention to detail: Programmers must be meticulous and detail-oriented to ensure high-quality code and minimize errors.
# * Flexibility: The programming field is constantly evolving, so programmers must be adaptable and willing to pivot when necessary.
#
# In summary, computer programmers are a diverse group of individuals with unique backgrounds, experiences, and characteristics. While some may have a traditional educational background or a specific specialization, others may have learned programming skills through non-traditional means or come from unexpected industries. What unites programmers is their passion for technology, innovation, and problem-solving, as well as their commitment to lifelong learning and collaboration.

# %% [markdown]
# #Creating Inclusive Prompts

# %%
def create_inclusive_prompt(topic):
    """Creates an inclusive prompt template for a given topic."""
    return PromptTemplate(
        input_variables=["topic"],
        template="Provide a balanced and inclusive perspective on {topic}, considering diverse viewpoints, experiences, and cultural contexts."
    )

topics = ["leadership", "family structures", "beauty standards"]

for topic in topics:
    prompt = create_inclusive_prompt(topic)
    response = (prompt | llm).invoke({"topic": topic}).content
    print(f"Inclusive perspective on {topic}:")
    print(response)
    print("\n" + "-"*50 + "\n")
# Out:
# Inclusive perspective on leadership:
# Leadership is a multifaceted concept that encompasses various perspectives, experiences, and cultural contexts. A balanced and inclusive perspective on leadership acknowledges and respects the diversity of individuals, groups, and societies, and recognizes that leadership is not a one-size-fits-all approach.
#
# **Inclusive Leadership**
#
# Inclusive leadership values diversity, equity, and social justice, and seeks to create an environment where everyone feels valued, respected, and empowered. This approach recognizes that leadership is not limited to a single individual or group, but rather is a collective effort that involves collaboration, empathy, and understanding.
#
# **Diverse Leadership Styles**
#
# Effective leaders adapt their leadership style to suit the needs of their team, organization, and community. This may involve:
#
# 1. **Authentic Leadership**: Leading from a place of vulnerability, empathy, and self-awareness.
# 2. **Transformational Leadership**: Fostering growth, innovation, and positive change through empowerment and collaboration.
# 3. **Servant Leadership**: Prioritizing the needs of others, and empowering them to achieve their goals.
# 4. **Inspirational Leadership**: Motivating and inspiring others through vision, passion, and positive energy.
#
# **Cultural Contexts**
#
# Leadership styles and approaches are influenced by cultural context, values, and norms. For example:
#
# 1. **Collectivist Cultures**: Leadership may emphasize group harmony, consensus, and cooperation.
# 2. **Individualist Cultures**: Leadership may prioritize personal achievement, innovation, and competition.
# 3. **Hierarchical Cultures**: Leadership may be characterized by authority, respect for tradition, and social hierarchy.
#
# **Challenging Assumptions**
#
# Leadership development programs and literature often perpetuate stereotypes and biases, which can limit the effectiveness of leadership development. Challenging these assumptions is crucial to promoting inclusive leadership:
#
# 1. **Breaking Down Gender Stereotypes**: Encouraging women to take on leadership roles and challenging traditional gender roles.
# 2. **Disrupting Racial and Ethnic Biases**: Recognizing the impact of systemic racism and promoting diversity, equity, and inclusion.
# 3. **Embracing Neurodiversity**: Fostering understanding and acceptance of individuals with neurodevelopmental disorders.
#
# **Key Principles**
#
# A balanced and inclusive perspective on leadership embodies the following principles:
#
# 1. **Embracing Diversity**: Recognizing and valuing differences in background, experience, and perspective.
# 2. **Fostering Inclusion**: Creating an environment that is welcoming, respectful, and empowering for all individuals.
# 3. **Promoting Equity**: Addressing systemic inequalities and ensuring fair access to opportunities and resources.
# 4. **Encouraging Collaboration**: Building consensus, fostering cooperation, and leveraging diverse perspectives.
# 5. **Embracing Continuous Learning**: Recognizing that leadership development is a lifelong process, and seeking feedback and growth opportunities.
#
# **Conclusion**
#
# Leadership is a complex and multifaceted concept that requires a balanced and inclusive perspective. By recognizing and respecting the diversity of individuals, groups, and societies, leaders can create a more equitable, just, and effective leadership approach.
#
# --------------------------------------------------
#
# Inclusive perspective on family structures:
# Family structures are complex and diverse, encompassing various forms, functions, and dynamics. It is essential to acknowledge and respect the diverse experiences and cultural contexts of families around the world. Here, we will explore the different types of family structures, their characteristics, and the importance of inclusivity and understanding.
#
# **Traditional Nuclear Family**
#
# A traditional nuclear family consists of a married couple and their biological children. This structure is often associated with Western cultures and is considered the "norm" in many societies. However, this structure is not universal and may not be representative of other cultures or experiences.
#
# **Extended Family**
#
# Extended families include multiple generations living together, such as grandparents, aunts, uncles, and cousins. This structure is common in many cultures, particularly in Asia, Africa, and Latin America. Extended families often provide emotional and financial support, as well as a sense of community and belonging.
#
# **Blended Families**
#
# Blended families, also known as stepfamilies, occur when two parents and their children from previous relationships merge. This structure can be challenging, as individuals may face adjustment difficulties and conflicting loyalties. However, blended families can also provide opportunities for new relationships and a sense of belonging.
#
# **Single-Parent Families**
#
# Single-parent families, where one parent raises the children without the presence of the other parent, are becoming increasingly common. This structure can be challenging, as the single parent may face financial and emotional stress. However, many single parents are resilient and resourceful, and their children often benefit from the increased attention and investment.
#
# **LGBTQ+ Families**
#
# LGBTQ+ families, including same-sex couples and non-binary parents, are increasingly visible and recognized. These families may face unique challenges, such as discrimination and lack of legal recognition, but they also provide a rich diversity of experiences and perspectives.
#
# **Foster and Adoptive Families**
#
# Foster and adoptive families involve caregivers who provide temporary or permanent care for children who are unable to live with their biological parents. These families provide critical support and stability for children who have experienced trauma or neglect.
#
# **Non-Traditional Families**
#
# Non-traditional families include those that do not conform to traditional gender roles or family structures. Examples include polyamorous families, where multiple partners are recognized as family members, and single-gender families, where all members are the same gender.
#
# **Importance of Inclusivity**
#
# It is essential to recognize and respect the diversity of family structures and experiences. This includes:
#
# 1. **Language and terminology**: Use inclusive language and avoid making assumptions about family structures or terminology.
# 2. **Representation and visibility**: Include diverse family structures in media, education, and public spaces to promote understanding and visibility.
# 3. **Support and resources**: Provide support and resources for families that may face unique challenges, such as discrimination or lack of legal recognition.
# 4. **Inclusive policies and laws**: Advocate for policies and laws that recognize and support diverse family structures, such as same-sex marriage and adoption rights.
#
# **Conclusion**
#
# Family structures are complex, diverse, and constantly evolving. It is essential to acknowledge and respect the unique experiences, cultural contexts, and perspectives of families around the world. By promoting inclusivity, understanding, and support, we can create a more equitable and just society for all families.
#
# --------------------------------------------------
#
# Inclusive perspective on beauty standards:
# Beauty standards are a complex and multifaceted concept that can vary greatly across cultures, societies, and individuals. What is considered beautiful can be influenced by a multitude of factors, including cultural background, personal experiences, and societal norms. Here is a balanced and inclusive perspective on beauty standards, considering diverse viewpoints, experiences, and cultural contexts:
#
# **Cultural Diversity:**
#
# * Beauty standards are shaped by cultural norms, values, and beliefs. For example, in some African cultures, dark skin is considered a symbol of beauty and status, while in some Asian cultures, fair skin is valued.
# * Different cultures have unique beauty standards, such as the emphasis on facial tattoos in some Pacific Island cultures or the importance of elaborate hairstyles in African cultures.
# * Cultural diversity should be celebrated and respected, and beauty standards should not be homogenized or assimilated to a single standard.
#
# **Inclusive Language:**
#
# * Language plays a significant role in shaping beauty standards. Using inclusive language, such as "beauty is diverse" or "beauty has no bounds," can help promote a positive and accepting attitude towards different beauty standards.
# * Avoiding language that perpetuates harmful stereotypes or biases, such as "traditional" or "western" beauty standards, can help create a more inclusive environment.
#
# **Intersectionality:**
#
# * Beauty standards can intersect with other social factors, such as race, gender, sexuality, class, and disability. For example, a woman of color may face different beauty standards and expectations than a white woman.
# * Intersectionality recognizes that individuals have multiple identities and experiences that intersect and influence their understanding of beauty standards.
#
# **Personal Experience:**
#
# * Personal experiences and self-perception play a significant role in shaping beauty standards. Individuals may have their own unique beauty standards that differ from societal norms or cultural expectations.
# * Encouraging self-acceptance and self-love can help individuals develop a positive relationship with their own beauty standards.
#
# **Societal Pressure:**
#
# * Societal pressure can greatly influence beauty standards, often perpetuating unrealistic and unattainable beauty ideals. This can lead to negative body image, low self-esteem, and mental health issues.
# * Promoting positive body image and self-acceptance can help individuals develop a healthier relationship with beauty standards.
#
# **Celebrating Diversity:**
#
# * Celebrating diversity and inclusivity can help promote a more positive and accepting attitude towards different beauty standards.
# * Encouraging representation and visibility of diverse beauty standards can help create a more inclusive environment.
#
# **Conclusion:**
#
# Beauty standards are complex and multifaceted, influenced by a range of factors, including cultural background, personal experiences, and societal norms. A balanced and inclusive perspective on beauty standards recognizes the diversity of beauty standards across cultures and individuals. By promoting inclusivity, celebrating diversity, and encouraging self-acceptance, we can work towards a more positive and accepting attitude towards beauty standards.
#
# **Key Takeaways:**
#
# 1. Beauty standards are shaped by cultural norms, values, and beliefs.
# 2. Inclusive language and representation can help promote a positive and accepting attitude towards different beauty standards.
# 3. Intersectionality recognizes that individuals have multiple identities and experiences that intersect and influence their understanding of beauty standards.
# 4. Personal experiences and self-perception play a significant role in shaping beauty standards.
# 5. Societal pressure can perpetuate unrealistic and unattainable beauty ideals.
# 6. Celebrating diversity and promoting inclusivity can help create a more positive and accepting attitude towards beauty standards.
#
# By acknowledging and respecting the diversity of beauty standards, we can work towards a more inclusive and positive environment that celebrates individuality and promotes self-acceptance.
#
# --------------------------------------------------

# %% [markdown]
# #Evaluating Fairness in a prompt

# %%
def evaluate_fairness(text):
    """Evaluates the fairness of a given text."""
    evaluation_prompt = PromptTemplate(
        input_variables=["text"],
        template="Evaluate the following text for fairness and inclusivity. Identify any potential biases or exclusionary language. Provide a fairness score from 1 to 10, where 10 is most fair and inclusive:\n\nText: {text}\n\nEvaluation:"
    )
    return (evaluation_prompt | llm).invoke({"text": text}).content

sample_text = "In the corporate world, strong leaders are often characterized by their decisiveness and ability to command respect."
fairness_evaluation = evaluate_fairness(sample_text)
print("Fairness Evaluation:")
print(fairness_evaluation)
# Out:
# Fairness Evaluation:
# The text appears to have some biases and exclusionary language that may impact its fairness and inclusivity. Here's a breakdown:
#
# * The phrase "strong leaders" implies that only certain types of leaders are valued or recognized, which may exclude others who don't fit this mold. This could be a problem for leaders who are more collaborative or consensus-driven, for example.
# * The emphasis on "decisiveness" as a key characteristic suggests that leaders who are more deliberative or open to feedback may be seen as less effective. This could be a problem for leaders who value diverse perspectives and want to involve others in decision-making.
# * The phrase "ability to command respect" implies that respect is earned through authority or dominance, rather than through empathy, active listening, or other forms of leadership that don't rely on coercion.
#
# Given these issues, I would give the text a fairness score of 6 out of 10. While the text does not explicitly exclude certain groups or individuals, its language and emphasis on certain leadership traits may create an implicit bias that favors certain types of leaders over others.
#
# To make the text more fair and inclusive, it might be helpful to rephrase it to include a broader range of leadership styles and characteristics, such as:
#
# "In the corporate world, effective leaders are often characterized by their ability to build strong relationships, listen actively, and make informed decisions that take into account diverse perspectives."
#
# This revised text is more inclusive and recognizes that there is no one-size-fits-all approach to leadership.
